# %%
import pandas as pd
import glob
import os
import numpy as np

# %%
import datetime
import timestring
from dateutil.relativedelta import relativedelta

import plotly.express as pt

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,6)

import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
globbed_files = glob.glob("*day.csv")

# %%
data = []

for csv in globbed_files:
    frame = pd.read_csv(csv, sep=';')
    frame['day'] = os.path.splitext(csv)[0]
    data.append(frame)

# %%
df = pd.concat([data[0], data[1], data[2], data[3], data[4]], axis=0)

# %%
df['day'].unique()
# Out:
# array(['tuesday', 'monday', 'thursday', 'wednesday', 'friday'],
#       dtype=object)

# %%
df['ID'] = df['customer_no'].apply(lambda x: '{0:0>4}'.format(x))

# %%
df.shape
# Out:
# (24877, 5)

# %%
dummy = pd.get_dummies(df['day'])

# %%
dummy['week_code'] = dummy.astype(str).agg(''.join,axis=1)

# %%
dummy
# Out:
#       friday  monday  thursday  tuesday  wednesday week_code
# 0          0       0         0        1          0     00010
# 1          0       0         0        1          0     00010
# 2          0       0         0        1          0     00010
# 3          0       0         0        1          0     00010
# 4          0       0         0        1          0     00010
# ...      ...     ...       ...      ...        ...       ...
# 5120       1       0         0        0          0     10000
# 5121       1       0         0        0          0     10000
# 5122       1       0         0        0          0     10000
# 5123       1       0         0        0          0     10000
# 5124       1       0         0        0          0     10000
#
# [24877 rows x 6 columns]

# %%
dummy['week_code'].unique()
# Out:
# array(['00010', '01000', '00100', '00001', '10000'], dtype=object)

# %%
df
# Out:
#                 timestamp  customer_no  location      day    ID
# 0     2019-09-03 07:02:00            1     fruit  tuesday  0001
# 1     2019-09-03 07:02:00            2    drinks  tuesday  0002
# 2     2019-09-03 07:03:00            3     dairy  tuesday  0003
# 3     2019-09-03 07:05:00            1    drinks  tuesday  0001
# 4     2019-09-03 07:06:00            4     dairy  tuesday  0004
# ...                   ...          ...       ...      ...   ...
# 5120  2019-09-06 21:50:00         1500     dairy   friday  1500
# 5121  2019-09-06 21:50:00         1507  checkout   friday  1507
# 5122  2019-09-06 21:50:00         1508  checkout   friday  1508
# 5123  2019-09-06 21:50:00         1509    drinks   friday  1509
# 5124  2019-09-06 21:50:00         1510    spices   friday  1510
#
# [24877 rows x 5 columns]

# %%
df = pd.concat([df, dummy['week_code']], axis=1)

# %%
df
# Out:
#                 timestamp  customer_no  location      day    ID week_code
# 0     2019-09-03 07:02:00            1     fruit  tuesday  0001     00010
# 1     2019-09-03 07:02:00            2    drinks  tuesday  0002     00010
# 2     2019-09-03 07:03:00            3     dairy  tuesday  0003     00010
# 3     2019-09-03 07:05:00            1    drinks  tuesday  0001     00010
# 4     2019-09-03 07:06:00            4     dairy  tuesday  0004     00010
# ...                   ...          ...       ...      ...   ...       ...
# 5120  2019-09-06 21:50:00         1500     dairy   friday  1500     10000
# 5121  2019-09-06 21:50:00         1507  checkout   friday  1507     10000
# 5122  2019-09-06 21:50:00         1508  checkout   friday  1508     10000
# 5123  2019-09-06 21:50:00         1509    drinks   friday  1509     10000
# 5124  2019-09-06 21:50:00         1510    spices   friday  1510     10000
#
# [24877 rows x 6 columns]

# %%
df['ID'] = df['week_code'] + df['ID']

# %%
df
# Out:
#                 timestamp  customer_no  location      day         ID week_code
# 0     2019-09-03 07:02:00            1     fruit  tuesday  000100001     00010
# 1     2019-09-03 07:02:00            2    drinks  tuesday  000100002     00010
# 2     2019-09-03 07:03:00            3     dairy  tuesday  000100003     00010
# 3     2019-09-03 07:05:00            1    drinks  tuesday  000100001     00010
# 4     2019-09-03 07:06:00            4     dairy  tuesday  000100004     00010
# ...                   ...          ...       ...      ...        ...       ...
# 5120  2019-09-06 21:50:00         1500     dairy   friday  100001500     10000
# 5121  2019-09-06 21:50:00         1507  checkout   friday  100001507     10000
# 5122  2019-09-06 21:50:00         1508  checkout   friday  100001508     10000
# 5123  2019-09-06 21:50:00         1509    drinks   friday  100001509     10000
# 5124  2019-09-06 21:50:00         1510    spices   friday  100001510     10000
#
# [24877 rows x 6 columns]

# %% [markdown]
# ### Calculate the total number of customers in each section

# %%
df.groupby(['day', 'ID']).count()
# Out:
#                      timestamp  customer_no  location  week_code
# day       ID
# friday    100000001          3            3         3          3
#           100000002          2            2         2          2
#           100000003          4            4         4          4
#           100000004          2            2         2          2
#           100000005          6            6         6          6
# ...                        ...          ...       ...        ...
# wednesday 000011527          3            3         3          3
#           000011528          2            2         2          2
#           000011529          3            3         3          3
#           000011530          3            3         3          3
#           000011531          2            2         2          2
#
# [7445 rows x 4 columns]

# %%
total_customer_day = df.groupby(['day', 'location']).size().to_frame()

# %%
total_customer_day.reset_index(inplace=True)

# %%
total_customer_day.plot(kind='bar', x='day')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
bar2 = sns.barplot(x='day', y=total_customer_day[0], data=total_customer_day, estimator=sum, ci=None, hue='location',  color='blue')

# %% [markdown]
# ### Get Entry Time

# %%
entry = df.groupby('ID')['timestamp']

# %%
df = df.assign(enter_at=entry.transform(min))

# %%
df.loc[df['ID'] == '000100001']
# Out:
#               timestamp  customer_no  location      day         ID week_code  \
# 0   2019-09-03 07:02:00            1     fruit  tuesday  000100001     00010
# 3   2019-09-03 07:05:00            1    drinks  tuesday  000100001     00010
# 25  2019-09-03 07:12:00            1  checkout  tuesday  000100001     00010
#
#                enter_at
# 0   2019-09-03 07:02:00
# 3   2019-09-03 07:02:00
# 25  2019-09-03 07:02:00

# %%
df['entry'] = np.where(df['timestamp'] == df['enter_at'], True, False)

# %%
df.loc[df['ID'] == '000100001']
# Out:
#               timestamp  customer_no  location      day         ID week_code  \
# 0   2019-09-03 07:02:00            1     fruit  tuesday  000100001     00010
# 3   2019-09-03 07:05:00            1    drinks  tuesday  000100001     00010
# 25  2019-09-03 07:12:00            1  checkout  tuesday  000100001     00010
#
#                enter_at  entry
# 0   2019-09-03 07:02:00   True
# 3   2019-09-03 07:02:00  False
# 25  2019-09-03 07:02:00  False

# %%
df.loc[df['entry'] == True].groupby(['day','location']).size()
# Out:
# day        location
# friday     dairy       398
#            drinks      234
#            fruit       586
#            spices      292
# monday     dairy       412
#            drinks      232
#            fruit       520
#            spices      283
# thursday   dairy       453
#            drinks      218
#            fruit       566
#            spices      298
# tuesday    dairy       416
#            drinks      220
#            fruit       559
#            spices      227
# wednesday  dairy       462
#            drinks      239
#            fruit       579
#            spices      251
# dtype: int64

# %% [markdown]
# ### Create row for entry

# %%
df_test = df.groupby('ID')

# %%
df_test

# %%
entry_row = df.loc[df['entry'] == True]

# %%
entry_row['location'] = 'checkin'
entry_row
# Out:
#                 timestamp  customer_no location      day         ID week_code  \
# 0     2019-09-03 07:02:00            1  checkin  tuesday  000100001     00010
# 1     2019-09-03 07:02:00            2  checkin  tuesday  000100002     00010
# 2     2019-09-03 07:03:00            3  checkin  tuesday  000100003     00010
# 4     2019-09-03 07:06:00            4  checkin  tuesday  000100004     00010
# 5     2019-09-03 07:06:00            5  checkin  tuesday  000100005     00010
# ...                   ...          ...      ...      ...        ...       ...
# 5112  2019-09-06 21:48:00         1506  checkin   friday  100001506     10000
# 5113  2019-09-06 21:48:00         1507  checkin   friday  100001507     10000
# 5114  2019-09-06 21:48:00         1508  checkin   friday  100001508     10000
# 5123  2019-09-06 21:50:00         1509  checkin   friday  100001509     10000
# 5124  2019-09-06 21:50:00         1510  checkin   friday  100001510     10000
#
#                  enter_at  entry
# 0     2019-09-03 07:02:00   True
# 1     2019-09-03 07:02:00   True
# 2     2019-09-03 07:03:00   True
# 4     2019-09-03 07:06:00   True
# 5     2019-09-03 07:06:00   True
# ...                   ...    ...
# 5112  2019-09-06 21:48:00   True
# 5113  2019-09-06 21:48:00   True
# 5114  2019-09-06 21:48:00   True
# 5123  2019-09-06 21:50:00   True
# 5124  2019-09-06 21:50:00   True
#
# [7445 rows x 8 columns]

# %%
X = 1
entry_row['timestamp'] = pd.to_datetime(entry_row['timestamp']) - datetime.timedelta(seconds=X)

# %%
entry_row
# Out:
#                timestamp  customer_no location      day         ID week_code  \
# 0    2019-09-03 07:01:59            1  checkin  tuesday  000100001     00010
# 1    2019-09-03 07:01:59            2  checkin  tuesday  000100002     00010
# 2    2019-09-03 07:02:59            3  checkin  tuesday  000100003     00010
# 4    2019-09-03 07:05:59            4  checkin  tuesday  000100004     00010
# 5    2019-09-03 07:05:59            5  checkin  tuesday  000100005     00010
# ...                  ...          ...      ...      ...        ...       ...
# 5112 2019-09-06 21:47:59         1506  checkin   friday  100001506     10000
# 5113 2019-09-06 21:47:59         1507  checkin   friday  100001507     10000
# 5114 2019-09-06 21:47:59         1508  checkin   friday  100001508     10000
# 5123 2019-09-06 21:49:59         1509  checkin   friday  100001509     10000
# 5124 2019-09-06 21:49:59         1510  checkin   friday  100001510     10000
#
#                  enter_at  entry
# 0     2019-09-03 07:02:00   True
# 1     2019-09-03 07:02:00   True
# 2     2019-09-03 07:03:00   True
# 4     2019-09-03 07:06:00   True
# 5     2019-09-03 07:06:00   True
# ...                   ...    ...
# 5112  2019-09-06 21:48:00   True
# 5113  2019-09-06 21:48:00   True
# 5114  2019-09-06 21:48:00   True
# 5123  2019-09-06 21:50:00   True
# 5124  2019-09-06 21:50:00   True
#
# [7445 rows x 8 columns]

# %%
df = df.append(entry_row, ignore_index=True, sort=True)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df['location'].unique()
# Out:
# array(['fruit', 'drinks', 'dairy', 'spices', 'checkout', 'checkin'],
#       dtype=object)

# %%
df.sort_values(by=['ID', 'timestamp'], inplace=True)

# %% [markdown]
# ### Get Checkout Time

# %%
checkout = df.groupby('ID')['timestamp']

# %%
df = df.assign(checkout_at=checkout.transform(max))

# %%
df.loc[df['ID'] == '000100001']
# Out:
#               ID  customer_no      day             enter_at  entry  location  \
# 24877  000100001            1  tuesday  2019-09-03 07:02:00   True   checkin
# 0      000100001            1  tuesday  2019-09-03 07:02:00   True     fruit
# 3      000100001            1  tuesday  2019-09-03 07:02:00  False    drinks
# 25     000100001            1  tuesday  2019-09-03 07:02:00  False  checkout
#
#                 timestamp week_code         checkout_at
# 24877 2019-09-03 07:01:59     00010 2019-09-03 07:12:00
# 0     2019-09-03 07:02:00     00010 2019-09-03 07:12:00
# 3     2019-09-03 07:05:00     00010 2019-09-03 07:12:00
# 25    2019-09-03 07:12:00     00010 2019-09-03 07:12:00

# %%
df['checkout'] = np.where(df['timestamp'] == df['checkout_at'], True, False)

# %%
df.loc[df['ID'] == '000100001']
# Out:
#               ID  customer_no      day             enter_at  entry  location  \
# 24877  000100001            1  tuesday  2019-09-03 07:02:00   True   checkin
# 0      000100001            1  tuesday  2019-09-03 07:02:00   True     fruit
# 3      000100001            1  tuesday  2019-09-03 07:02:00  False    drinks
# 25     000100001            1  tuesday  2019-09-03 07:02:00  False  checkout
#
#                 timestamp week_code         checkout_at  checkout
# 24877 2019-09-03 07:01:59     00010 2019-09-03 07:12:00     False
# 0     2019-09-03 07:02:00     00010 2019-09-03 07:12:00     False
# 3     2019-09-03 07:05:00     00010 2019-09-03 07:12:00     False
# 25    2019-09-03 07:12:00     00010 2019-09-03 07:12:00      True

# %%
df.loc[df['checkout'] == True].groupby(['location']).size()
# Out:
# location
# checkout    7417
# dairy         14
# drinks         2
# fruit          7
# spices         5
# dtype: int64

# %%
checkout_all = df.loc[df['checkout'] == True]

# %%
checkout_without_purchase = checkout_all.loc[checkout_all['location'] != 'checkout']

# %%
checkout_without_purchase.groupby('day').size()
# Out:
# day
# friday        8
# monday       10
# thursday      3
# tuesday       2
# wednesday     5
# dtype: int64

# %%
df.loc[df['location'] == 'checkout'].groupby(['day','location']).size()
# Out:
# day        location
# friday     checkout    1510
# monday     checkout    1447
# thursday   checkout    1535
# tuesday    checkout    1422
# wednesday  checkout    1531
# dtype: int64

# %%
checkout_row = df.loc[((df['checkout'] == True ) & (df['location'] != 'checkout'))]

# %%
checkout_row['location'] = 'checkout'
checkout_row
# Out:
#               ID  customer_no        day             enter_at  entry  \
# 19748  000011520         1520  wednesday  2019-09-04 21:40:00  False
# 19742  000011527         1527  wednesday  2019-09-04 21:44:00  False
# 19747  000011528         1528  wednesday  2019-09-04 21:45:00  False
# 19749  000011529         1529  wednesday  2019-09-04 21:45:00  False
# 19750  000011530         1530  wednesday  2019-09-04 21:46:00  False
# 4713   000101411         1411    tuesday  2019-09-03 21:29:00  False
# 4710   000101422         1422    tuesday  2019-09-03 21:46:00  False
# 14694  001001527         1527   thursday  2019-09-05 21:35:00  False
# 14696  001001532         1532   thursday  2019-09-05 21:48:00   True
# 14697  001001533         1533   thursday  2019-09-05 21:48:00   True
# 9589   010001430         1430     monday  2019-09-02 21:38:00  False
# 9590   010001433         1433     monday  2019-09-02 21:40:00  False
# 9577   010001437         1437     monday  2019-09-02 21:43:00  False
# 9574   010001439         1439     monday  2019-09-02 21:46:00   True
# 9591   010001440         1440     monday  2019-09-02 21:46:00  False
# 9592   010001441         1441     monday  2019-09-02 21:47:00  False
# 9587   010001443         1443     monday  2019-09-02 21:47:00  False
# 9595   010001445         1445     monday  2019-09-02 21:49:00   True
# 9596   010001446         1446     monday  2019-09-02 21:50:00   True
# 9597   010001447         1447     monday  2019-09-02 21:50:00   True
# 24867  100001494         1494     friday  2019-09-06 21:32:00  False
# 24871  100001496         1496     friday  2019-09-06 21:35:00  False
# 24872  100001500         1500     friday  2019-09-06 21:41:00  False
# 24869  100001503         1503     friday  2019-09-06 21:47:00  False
# 24870  100001505         1505     friday  2019-09-06 21:48:00  False
# 24864  100001506         1506     friday  2019-09-06 21:48:00   True
# 24875  100001509         1509     friday  2019-09-06 21:50:00   True
# 24876  100001510         1510     friday  2019-09-06 21:50:00   True
#
#        location           timestamp week_code         checkout_at  checkout
# 19748  checkout 2019-09-04 21:49:00     00001 2019-09-04 21:49:00      True
# 19742  checkout 2019-09-04 21:47:00     00001 2019-09-04 21:47:00      True
# 19747  checkout 2019-09-04 21:48:00     00001 2019-09-04 21:48:00      True
# 19749  checkout 2019-09-04 21:49:00     00001 2019-09-04 21:49:00      True
# 19750  checkout 2019-09-04 21:49:00     00001 2019-09-04 21:49:00      True
# 4713   checkout 2019-09-03 21:50:00     00010 2019-09-03 21:50:00      True
# 4710   checkout 2019-09-03 21:47:00     00010 2019-09-03 21:47:00      True
# 14694  checkout 2019-09-05 21:47:00     00100 2019-09-05 21:47:00      True
# 14696  checkout 2019-09-05 21:48:00     00100 2019-09-05 21:48:00      True
# 14697  checkout 2019-09-05 21:48:00     00100 2019-09-05 21:48:00      True
# 9589   checkout 2019-09-02 21:49:00     01000 2019-09-02 21:49:00      True
# 9590   checkout 2019-09-02 21:49:00     01000 2019-09-02 21:49:00      True
# 9577   checkout 2019-09-02 21:47:00     01000 2019-09-02 21:47:00      True
# 9574   checkout 2019-09-02 21:46:00     01000 2019-09-02 21:46:00      True
# 9591   checkout 2019-09-02 21:49:00     01000 2019-09-02 21:49:00      True
# 9592   checkout 2019-09-02 21:49:00     01000 2019-09-02 21:49:00      True
# 9587   checkout 2019-09-02 21:48:00     01000 2019-09-02 21:48:00      True
# 9595   checkout 2019-09-02 21:49:00     01000 2019-09-02 21:49:00      True
# 9596   checkout 2019-09-02 21:50:00     01000 2019-09-02 21:50:00      True
# 9597   checkout 2019-09-02 21:50:00     01000 2019-09-02 21:50:00      True
# 24867  checkout 2019-09-06 21:49:00     10000 2019-09-06 21:49:00      True
# 24871  checkout 2019-09-06 21:50:00     10000 2019-09-06 21:50:00      True
# 24872  checkout 2019-09-06 21:50:00     10000 2019-09-06 21:50:00      True
# 24869  checkout 2019-09-06 21:49:00     10000 2019-09-06 21:49:00      True
# 24870  checkout 2019-09-06 21:49:00     10000 2019-09-06 21:49:00      True
# 24864  checkout 2019-09-06 21:48:00     10000 2019-09-06 21:48:00      True
# 24875  checkout 2019-09-06 21:50:00     10000 2019-09-06 21:50:00      True
# 24876  checkout 2019-09-06 21:50:00     10000 2019-09-06 21:50:00      True

# %%
X = 1
checkout_row['timestamp'] = pd.to_datetime(checkout_row['timestamp']) + datetime.timedelta(minutes=X)

# %%
checkout_row.count()
# Out:
# ID             28
# customer_no    28
# day            28
# enter_at       28
# entry          28
# location       28
# timestamp      28
# week_code      28
# checkout_at    28
# checkout       28
# dtype: int64

# %%
df = df.append(checkout_row, ignore_index=True, sort=True)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df['location'].unique()
# Out:
# array(['checkin', 'fruit', 'checkout', 'dairy', 'spices', 'drinks'],
#       dtype=object)

# %%
df.sort_values(by=['ID', 'timestamp'], inplace=True)

# %%
len(set(df['ID']))
# Out:
# 7445

# %% [markdown]
# ### Time Spent (total)

# %%
df['time_spent'] = (pd.to_datetime(df['checkout_at']) - pd.to_datetime(df['enter_at']))

# %%
df['time_spent_m'] = df['time_spent'].dt.components['minutes']

# %%
df['time_spent_m'].mean()
# Out:
# 8.228748068006182

# %% [markdown]
# ### Sequencing

# %%
df['sequence'] = df.groupby(['ID']).cumcount()+0

# %%
df[['timestamp', 'ID', 'location', 'sequence']]
# Out:
#                 timestamp         ID  location  sequence
# 0     2019-09-04 06:59:59  000010001   checkin         0
# 1     2019-09-04 07:00:00  000010001     fruit         1
# 2     2019-09-04 07:02:00  000010001  checkout         2
# 3     2019-09-04 06:59:59  000010002   checkin         0
# 4     2019-09-04 07:00:00  000010002     dairy         1
# ...                   ...        ...       ...       ...
# 32319 2019-09-06 21:50:00  100001509    drinks         1
# 32348 2019-09-06 21:51:00  100001509  checkout         2
# 32320 2019-09-06 21:49:59  100001510   checkin         0
# 32321 2019-09-06 21:50:00  100001510    spices         1
# 32349 2019-09-06 21:51:00  100001510  checkout         2
#
# [32350 rows x 4 columns]

# %%
df.sort_values(by=['ID', 'timestamp'])
# Out:
#               ID  checkout         checkout_at  customer_no        day  \
# 0      000010001     False 2019-09-04 07:02:00            1  wednesday
# 1      000010001     False 2019-09-04 07:02:00            1  wednesday
# 2      000010001      True 2019-09-04 07:02:00            1  wednesday
# 3      000010002     False 2019-09-04 07:06:00            2  wednesday
# 4      000010002     False 2019-09-04 07:06:00            2  wednesday
# ...          ...       ...                 ...          ...        ...
# 32319  100001509      True 2019-09-06 21:50:00         1509     friday
# 32348  100001509      True 2019-09-06 21:50:00         1509     friday
# 32320  100001510     False 2019-09-06 21:50:00         1510     friday
# 32321  100001510      True 2019-09-06 21:50:00         1510     friday
# 32349  100001510      True 2019-09-06 21:50:00         1510     friday
#
#                   enter_at  entry  location           timestamp week_code  \
# 0      2019-09-04 07:00:00   True   checkin 2019-09-04 06:59:59     00001
# 1      2019-09-04 07:00:00   True     fruit 2019-09-04 07:00:00     00001
# 2      2019-09-04 07:00:00  False  checkout 2019-09-04 07:02:00     00001
# 3      2019-09-04 07:00:00   True   checkin 2019-09-04 06:59:59     00001
# 4      2019-09-04 07:00:00   True     dairy 2019-09-04 07:00:00     00001
# ...                    ...    ...       ...                 ...       ...
# 32319  2019-09-06 21:50:00   True    drinks 2019-09-06 21:50:00     10000
# 32348  2019-09-06 21:50:00   True  checkout 2019-09-06 21:51:00     10000
# 32320  2019-09-06 21:50:00   True   checkin 2019-09-06 21:49:59     10000
# 32321  2019-09-06 21:50:00   True    spices 2019-09-06 21:50:00     10000
# 32349  2019-09-06 21:50:00   True  checkout 2019-09-06 21:51:00     10000
#
#            time_spent  time_spent_m  sequence
# 0     0 days 00:02:00             2         0
# 1     0 days 00:02:00             2         1
# 2     0 days 00:02:00             2         2
# 3     0 days 00:06:00             6         0
# 4     0 days 00:06:00             6         1
# ...               ...           ...       ...
# 32319 0 days 00:00:00             0         1
# 32348 0 days 00:00:00             0         2
# 32320 0 days 00:00:00             0         0
# 32321 0 days 00:00:00             0         1
# 32349 0 days 00:00:00             0         2
#
# [32350 rows x 13 columns]

# %%
df['sequence'].max()
# Out:
# 18

# %%
df['location'].unique()
# Out:
# array(['checkin', 'fruit', 'checkout', 'dairy', 'spices', 'drinks'],
#       dtype=object)

# %%
seq_1 = df.loc[df['sequence'] == 1]
seq_2 = df.loc[df['sequence'] == 2]

# %%
seq_1.groupby('location')['location'].hist()
# Out:
# location
# dairy     AxesSubplot(0.125,0.125;0.775x0.755)
# drinks    AxesSubplot(0.125,0.125;0.775x0.755)
# fruit     AxesSubplot(0.125,0.125;0.775x0.755)
# spices    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: location, dtype: object

# %%
seq_2.groupby('location')['location'].hist()
# Out:
# location
# checkout    AxesSubplot(0.125,0.125;0.775x0.755)
# dairy       AxesSubplot(0.125,0.125;0.775x0.755)
# drinks      AxesSubplot(0.125,0.125;0.775x0.755)
# fruit       AxesSubplot(0.125,0.125;0.775x0.755)
# spices      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: location, dtype: object

# %%
df[['timestamp', 'ID', 'location','sequence']].loc[df['ID'] < '000100100']

# %% [markdown]
# ### test transition matrix

# %%
df_test = df[['timestamp', 'ID', 'location','sequence']].loc[df['ID'] < '000100100']

# %%
df_test.sort_values(by=['ID', 'timestamp'])

# %%
df_test['shift'] = df_test.groupby(['ID'])['location'].shift(-1)

# %%
df_test.sort_values(by=['ID', 'timestamp'])

# %%
pd.crosstab(df_test['location'], df_test['shift'])

# %%
round(pd.crosstab(df_test['location'], df_test['shift'], normalize=0), 2)

# %%
pd.to_datetime(df['timestamp']).dt.day.unique()

# %%
df.to_hdf('input_t_mat.h5', key='df', mode='w')

# %%
df['ID']

# %%
df['ID'] = [str(x) for x in df['ID']]

# %%
df.to_csv('input_t_mat.csv')

# %%
df['checkout'].describe()
# Out:
# count     32350
# unique        2
# top       False
# freq      24877
# Name: checkout, dtype: object
